# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from google.colab import drive
drive.mount('/content/drive')

jan_sales = r'/content/drive/My Drive/Sales Dataset/Sales_January_2019.csv'
feb_sales = r'/content/drive/My Drive/Sales Dataset/Sales_February_2019.csv'
mar_sales = r'/content/drive/My Drive/Sales Dataset/Sales_March_2019.csv'
april_sales = r'/content/drive/My Drive/Sales Dataset/Sales_April_2019.csv'
may_sales = r'/content/drive/My Drive/Sales Dataset/Sales_May_2019.csv'
june_sales = r'/content/drive/My Drive/Sales Dataset/Sales_June_2019.csv'
july_sales = r'/content/drive/My Drive/Sales Dataset/Sales_July_2019.csv'
august_sales = r'/content/drive/My Drive/Sales Dataset/Sales_August_2019.csv'
sept_sales = r'/content/drive/My Drive/Sales Dataset/Sales_September_2019.csv'
oct_sales = r'/content/drive/My Drive/Sales Dataset/Sales_October_2019.csv'
nov_sales = r'/content/drive/My Drive/Sales Dataset/Sales_November_2019.csv'
dec_sales = r'/content/drive/My Drive/Sales Dataset/Sales_December_2019.csv'

import pandas as pd
jan = pd.read_csv(jan_sales)
feb = pd.read_csv(feb_sales)
mar = pd.read_csv(mar_sales)
april = pd.read_csv(april_sales)
may = pd.read_csv(may_sales)
june = pd.read_csv(june_sales)
july = pd.read_csv(july_sales)
august = pd.read_csv(august_sales)
sept = pd.read_csv(sept_sales)
october = pd.read_csv(oct_sales)
nov = pd.read_csv(nov_sales)
december = pd.read_csv(dec_sales)
# Out:
# Mounted at /content/drive

# %%
monthly_data = [jan, feb, mar, april, may, june, july, august, sept, october, nov, december]

all_sales_data = pd.concat(monthly_data, ignore_index=True)

all_sales_data
# Out:
#        Order ID                     Product Quantity Ordered Price Each  \
# 0        141234                      iPhone                1        700
# 1        141235    Lightning Charging Cable                1      14.95
# 2        141236            Wired Headphones                2      11.99
# 3        141237            27in FHD Monitor                1     149.99
# 4        141238            Wired Headphones                1      11.99
# ...         ...                         ...              ...        ...
# 186845   319666    Lightning Charging Cable                1      14.95
# 186846   319667       AA Batteries (4-pack)                2       3.84
# 186847   319668             Vareebadd Phone                1        400
# 186848   319669            Wired Headphones                1      11.99
# 186849   319670  Bose SoundSport Headphones                1      99.99
#
#             Order Date                        Purchase Address
# ...

# %%
all_sales_data.isna().sum()
# Out:
# Order ID            545
# Product             545
# Quantity Ordered    545
# Price Each          545
# Order Date          545
# Purchase Address    545
# dtype: int64

# %%
sales = all_sales_data.dropna()

# %%
sales.isna().sum()
# Out:
# Order ID            0
# Product             0
# Quantity Ordered    0
# Price Each          0
# Order Date          0
# Purchase Address    0
# dtype: int64

# %%
sales
# Out:
#        Order ID                     Product Quantity Ordered Price Each  \
# 0        141234                      iPhone                1        700
# 1        141235    Lightning Charging Cable                1      14.95
# 2        141236            Wired Headphones                2      11.99
# 3        141237            27in FHD Monitor                1     149.99
# 4        141238            Wired Headphones                1      11.99
# ...         ...                         ...              ...        ...
# 186845   319666    Lightning Charging Cable                1      14.95
# 186846   319667       AA Batteries (4-pack)                2       3.84
# 186847   319668             Vareebadd Phone                1        400
# 186848   319669            Wired Headphones                1      11.99
# 186849   319670  Bose SoundSport Headphones                1      99.99
#
#             Order Date                        Purchase Address
# ...

# %%
sales['Order Date'] = pd.to_datetime(sales['Order Date'],errors='coerce')
sales
# Out:
# <ipython-input-8-857f1cc46e95>:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   sales['Order Date'] = pd.to_datetime(sales['Order Date'],errors='coerce')
# <ipython-input-8-857f1cc46e95>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sales['Order Date'] = pd.to_datetime(sales['Order Date'],errors='coerce')
#        Order ID                     Product Quantity Ordered Price Each  \
# 0        141234                      iPhone                1        700
# 1        141235    Lightning Charging Cable                1      14.95
# ...

# %%
sales_2019 = sales.dropna()

# %%
sales_2019
# Out:
#        Order ID                     Product Quantity Ordered Price Each  \
# 0        141234                      iPhone                1        700
# 1        141235    Lightning Charging Cable                1      14.95
# 2        141236            Wired Headphones                2      11.99
# 3        141237            27in FHD Monitor                1     149.99
# 4        141238            Wired Headphones                1      11.99
# ...         ...                         ...              ...        ...
# 186845   319666    Lightning Charging Cable                1      14.95
# 186846   319667       AA Batteries (4-pack)                2       3.84
# 186847   319668             Vareebadd Phone                1        400
# 186848   319669            Wired Headphones                1      11.99
# 186849   319670  Bose SoundSport Headphones                1      99.99
#
#                 Order Date                        Purchase Address
# ...

# %%
sales_2019.dtypes
# Out:
# Order ID                    object
# Product                     object
# Quantity Ordered            object
# Price Each                  object
# Order Date          datetime64[ns]
# Purchase Address            object
# dtype: object

# %%
# Convert 'Quantity Ordered' and 'Price Each' columns to float
sales_2019['Quantity Ordered'] = pd.to_numeric(sales_2019['Quantity Ordered'], errors='coerce')
sales_2019['Price Each'] = pd.to_numeric(sales_2019['Price Each'], errors='coerce')

# Check the data types and first few rows
print(sales_2019[['Quantity Ordered', 'Price Each']].dtypes)
print(sales_2019[['Quantity Ordered', 'Price Each']].head())
# Out:
# Quantity Ordered      int64
# Price Each          float64
# dtype: object
#    Quantity Ordered  Price Each
# 0                 1      700.00
# 1                 1       14.95
# 2                 2       11.99
# 3                 1      149.99
# 4                 1       11.99
# <ipython-input-12-7a0e5ea0789a>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sales_2019['Quantity Ordered'] = pd.to_numeric(sales_2019['Quantity Ordered'], errors='coerce')
# <ipython-input-12-7a0e5ea0789a>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
sales_2019.dtypes
# Out:
# Order ID                    object
# Product                     object
# Quantity Ordered             int64
# Price Each                 float64
# Order Date          datetime64[ns]
# Purchase Address            object
# dtype: object

# %%
sales_2019.isna().sum()
# Out:
# Order ID            0
# Product             0
# Quantity Ordered    0
# Price Each          0
# Order Date          0
# Purchase Address    0
# dtype: int64

# %%
sales_2019['Total Sales'] = sales_2019['Quantity Ordered'] * sales_2019['Price Each']
# Out:
# <ipython-input-15-0a8e1c5a47dd>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sales_2019['Total Sales'] = sales_2019['Quantity Ordered'] * sales_2019['Price Each']

# %%
sales_2019
# Out:
#        Order ID                     Product  Quantity Ordered  Price Each  \
# 0        141234                      iPhone                 1      700.00
# 1        141235    Lightning Charging Cable                 1       14.95
# 2        141236            Wired Headphones                 2       11.99
# 3        141237            27in FHD Monitor                 1      149.99
# 4        141238            Wired Headphones                 1       11.99
# ...         ...                         ...               ...         ...
# 186845   319666    Lightning Charging Cable                 1       14.95
# 186846   319667       AA Batteries (4-pack)                 2        3.84
# 186847   319668             Vareebadd Phone                 1      400.00
# 186848   319669            Wired Headphones                 1       11.99
# 186849   319670  Bose SoundSport Headphones                 1       99.99
#
#                 Order Date                        Purchase Address  \
# ...

# %%
df['Product'].unique()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-19-0756a0ca1ced> in <cell line: 0>()
# ----> 1 df['Product'].unique()
#
# NameError: name 'df' is not defined

# %%
product_category_mapping = {
    '34in Ultrawide Monitor': 'Electronics',
    '27in 4K Gaming Monitor': 'Electronics',
    'AAA Batteries (4-pack)': 'Accessories',
    '27in FHD Monitor': 'Electronics',
    'Wired Headphones': 'Electronics',
    'Lightning Charging Cable': 'Accessories',
    'Apple Airpods Headphones': 'Electronics',
    'USB-C Charging Cable': 'Accessories',
    '20in Monitor': 'Electronics',
    'iPhone': 'Electronics',
    'Bose SoundSport Headphones': 'Electronics',
    'ThinkPad Laptop': 'Electronics',
    'AA Batteries (4-pack)': 'Accessories',
    'Google Phone': 'Electronics',
    'Vareebadd Phone': 'Electronics',
    'Flatscreen TV': 'Electronics',
    'Macbook Pro Laptop': 'Electronics',
    'LG Dryer': 'Home Appliances',
    'LG Washing Machine': 'Home Appliances',
    'Product': 'Miscellaneous'
}

sales_2019['Category'] = sales_2019['Product'].map(product_category_mapping)
sales_2019
# Out:
# <ipython-input-20-092f697ef852>:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sales_2019['Category'] = sales_2019['Product'].map(product_category_mapping)
#        Order ID                     Product  Quantity Ordered  Price Each  \
# 0        141234                      iPhone                 1      700.00
# 1        141235    Lightning Charging Cable                 1       14.95
# 2        141236            Wired Headphones                 2       11.99
# 3        141237            27in FHD Monitor                 1      149.99
# 4        141238            Wired Headphones                 1       11.99
# ...         ...                         ...               ...         ...
# ...

# %%
sales_2019['City'] = sales_2019['Purchase Address'].str.split(',').str[1].str.strip()
sales_2019
# Out:
# <ipython-input-21-6374131d9642>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sales_2019['City'] = sales_2019['Purchase Address'].str.split(',').str[1].str.strip()
#        Order ID                     Product  Quantity Ordered  Price Each  \
# 0        141234                      iPhone                 1      700.00
# 1        141235    Lightning Charging Cable                 1       14.95
# 2        141236            Wired Headphones                 2       11.99
# 3        141237            27in FHD Monitor                 1      149.99
# 4        141238            Wired Headphones                 1       11.99
# ...         ...                         ...               ...         ...
# ...

# %%
file_path = '/content/sales_data.csv'
sales_2019.to_csv(file_path, index=False)

from google.colab import files
files.download(file_path)

# %%
sales_2019
# Out:
#        Order ID                     Product  Quantity Ordered  Price Each  \
# 0        141234                      iPhone                 1      700.00
# 1        141235    Lightning Charging Cable                 1       14.95
# 2        141236            Wired Headphones                 2       11.99
# 3        141237            27in FHD Monitor                 1      149.99
# 4        141238            Wired Headphones                 1       11.99
# ...         ...                         ...               ...         ...
# 186845   319666    Lightning Charging Cable                 1       14.95
# 186846   319667       AA Batteries (4-pack)                 2        3.84
# 186847   319668             Vareebadd Phone                 1      400.00
# 186848   319669            Wired Headphones                 1       11.99
# 186849   319670  Bose SoundSport Headphones                 1       99.99
#
#                 Order Date                        Purchase Address  \
# ...

# %%
sales_by_month = sales_2019.groupby('Month')['Total Sales'].sum()

sales_growth_percent = sales_by_month.pct_change() * 100

sales_growth_percent
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-23-2d8abe502f9c> in <cell line: 0>()
# ----> 1 sales_by_month = sales_2019.groupby('Month')['Total Sales'].sum()
#       2
#       3 sales_growth_percent = sales_by_month.pct_change() * 100
#       4
#       5 sales_growth_percent
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/frame.py in groupby(self, by, axis, level, as_index, sort, group_keys, observed, dropna)
#    9181             raise TypeError("You have to supply one of 'by' and 'level'")
#    9182
# -> 9183         return DataFrameGroupBy(
#    9184             obj=self,
#    9185             keys=by,
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/groupby/groupby.py in __init__(self, obj, keys, axis, level, grouper, exclusions, selection, as_index, sort, group_keys, observed, dropna)
#    1327
#    1328         if grouper is None:
# ...

# %%
sales_2019
# Out:
#        Order ID                     Product  Quantity Ordered  Price Each  \
# 0        141234                      iPhone                 1      700.00
# 1        141235    Lightning Charging Cable                 1       14.95
# 2        141236            Wired Headphones                 2       11.99
# 3        141237            27in FHD Monitor                 1      149.99
# 4        141238            Wired Headphones                 1       11.99
# ...         ...                         ...               ...         ...
# 186845   319666    Lightning Charging Cable                 1       14.95
# 186846   319667       AA Batteries (4-pack)                 2        3.84
# 186847   319668             Vareebadd Phone                 1      400.00
# 186848   319669            Wired Headphones                 1       11.99
# 186849   319670  Bose SoundSport Headphones                 1       99.99
#
#                 Order Date                        Purchase Address  \
# ...

# %%
sales_2019['Order Date'] = pd.to_datetime(sales_2019['Order Date'])

sales_data = sales_2019.groupby(['Order Date', 'Product'])['Quantity Ordered'].sum().reset_index()

# Prepare data for Prophet (one product at a time)
product_forecasts = {}
for product in sales_data['Product'].unique():
    product_data = sales_data[sales_data['Product'] == product][['Order Date', 'Quantity Ordered']]
    product_data.columns = ['ds', 'y']  # Prophet requires these column names

    from prophet import Prophet
    import matplotlib.pyplot as plt
    # Initialize Prophet model
    model = Prophet()
    model.fit(product_data)

    # Create future dates (next quarter)
    future = model.make_future_dataframe(periods=90)  # 90 days (approximately one quarter)
    forecast = model.predict(future)

    # Save forecast for the product
    product_forecasts[product] = forecast

    # Plot forecast
    model.plot(forecast)
    plt.title(f"Sales Forecast for {product}")
    plt.show()

# Analyze results
for product, forecast in product_forecasts.items():
    predicted_sales = forecast[['ds', 'yhat']].tail(90)  # Extract future predictions
    total_predicted_sales = predicted_sales['yhat'].sum()
    print(f"Predicted total sales for {product} in the next quarter: {total_predicted_sales:.2f}")
# Out:
# <ipython-input-26-97bc8228c89d>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sales_2019['Order Date'] = pd.to_datetime(sales_2019['Order Date'])
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp4huv5_76/hs9pxyvp.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp4huv5_76/m_trj8q9.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# ...
